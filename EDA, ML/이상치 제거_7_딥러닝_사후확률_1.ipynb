# %%
import numpy as np 
import pandas as pd
# 시각화 package
import matplotlib.pyplot as plt
import seaborn as sns
import graphviz
from sklearn.tree import export_graphviz

import matplotlib.font_manager as font_manager
from matplotlib import rc
   
# 한글폰트작업
# window의 폰트 위치 -> C:/Windows/Fonts/NGULIM.TTF
font_name = font_manager.FontProperties(fname="C:/Windows/Fonts/NGULIM.TTF").get_name()
rc('font', family=font_name)
plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# # <font color = 4247D6> Data Set

# %%
df = pd.read_csv('이상치_제거_.csv')
df
# Out:
#                   STD_DT  MELT_TEMP  MOTORSPEED  MELT_WEIGHT TAG
# 0        2020-03-04 0:00        489         116          631  OK
# 1        2020-03-04 0:00        433          78          609  OK
# 2        2020-03-04 0:00        464         154          608  OK
# 3        2020-03-04 0:00        379         212          606  OK
# 4        2020-03-04 0:00        798        1736          604  OK
# ...                  ...        ...         ...          ...  ..
# 835195  2020-04-30 23:59        755        1743          318  OK
# 835196  2020-04-30 23:59        385         206          317  OK
# 835197  2020-04-30 23:59        465         148          316  OK
# 835198  2020-04-30 23:59        467           0          314  OK
# 835199  2020-04-30 23:59        453         125          312  OK
#
# [835200 rows x 5 columns]

# %%
df.replace({'TAG': {'OK': 1, 'NG': 0}}, inplace=True)
df
# Out:
#                   STD_DT  MELT_TEMP  MOTORSPEED  MELT_WEIGHT  TAG
# 0        2020-03-04 0:00        489         116          631    1
# 1        2020-03-04 0:00        433          78          609    1
# 2        2020-03-04 0:00        464         154          608    1
# 3        2020-03-04 0:00        379         212          606    1
# 4        2020-03-04 0:00        798        1736          604    1
# ...                  ...        ...         ...          ...  ...
# 835195  2020-04-30 23:59        755        1743          318    1
# 835196  2020-04-30 23:59        385         206          317    1
# 835197  2020-04-30 23:59        465         148          316    1
# 835198  2020-04-30 23:59        467           0          314    1
# 835199  2020-04-30 23:59        453         125          312    1
#
# [835200 rows x 5 columns]

# %%
from datetime import datetime
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import *
from imblearn.over_sampling import SMOTE

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM
from tcn import TCN, tcn_full_summary
from keras.layers import Dropout
from keras.preprocessing import sequence
from keras.utils import np_utils
from keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
df['STD_DT'] = df['STD_DT'].apply(lambda x: pd.to_datetime(str(x), format = '%Y-%m-%d %H:%M:%S'))

# %%
df = df.set_index(['STD_DT'])
df
# Out:
#                      MELT_TEMP  MOTORSPEED  MELT_WEIGHT  TAG
# STD_DT
# 2020-03-04 00:00:00        489         116          631    1
# 2020-03-04 00:00:00        433          78          609    1
# 2020-03-04 00:00:00        464         154          608    1
# 2020-03-04 00:00:00        379         212          606    1
# 2020-03-04 00:00:00        798        1736          604    1
# ...                        ...         ...          ...  ...
# 2020-04-30 23:59:00        755        1743          318    1
# 2020-04-30 23:59:00        385         206          317    1
# 2020-04-30 23:59:00        465         148          316    1
# 2020-04-30 23:59:00        467           0          314    1
# 2020-04-30 23:59:00        453         125          312    1
#
# [835200 rows x 4 columns]

# %%
# df.replace({'TAG': {'OK': 1, 'NG': 0}}, inplace=True)
df1 = df[['MELT_TEMP', 'MOTORSPEED', 'MELT_WEIGHT', 'TAG']]
df1
# Out:
#                      MELT_TEMP  MOTORSPEED  MELT_WEIGHT  TAG
# STD_DT
# 2020-03-04 00:00:00        489         116          631    1
# 2020-03-04 00:00:00        433          78          609    1
# 2020-03-04 00:00:00        464         154          608    1
# 2020-03-04 00:00:00        379         212          606    1
# 2020-03-04 00:00:00        798        1736          604    1
# ...                        ...         ...          ...  ...
# 2020-04-30 23:59:00        755        1743          318    1
# 2020-04-30 23:59:00        385         206          317    1
# 2020-04-30 23:59:00        465         148          316    1
# 2020-04-30 23:59:00        467           0          314    1
# 2020-04-30 23:59:00        453         125          312    1
#
# [835200 rows x 4 columns]

# %%
split_date = int(df1.shape[0]*0.5)
# split_date = int(534902)
train = df1[:split_date]
test = df1[split_date:]
print(train.shape)
print(test.shape)
# Out:
# (417600, 4)
# (417600, 4)

# %%
df1['TAG'][:split_date].plot(figsize=(8, 5), legend=True, color= '#4192D6')
df1['TAG'][split_date:].plot(figsize=(8, 5), legend=True, color= '#d6d142')
plt.legend(['train', 'test'])
plt.title('train-test split')
plt.show()

# %%
scaler = preprocessing.MinMaxScaler()

train_sc = scaler.fit_transform(train)
test_sc = scaler.transform(test)

x_train_values = train_sc[:, :-1]
y_train_values = train_sc[:,-1]

# %%
smote = SMOTE(random_state = 0)

X_train_over, y_train_over = smote.fit_resample(x_train_values, y_train_values)
print('SMOTE 적용 전 학습용 피처/레이블 데이터 세트', x_train_values.shape, y_train_values.shape)
print('SMOTE 적용 후 학습용 피처/레이블 데이터 세트', X_train_over.shape, y_train_over.shape)
print('SMOTE 적용 후 레이블 값 분포: \n', pd.Series(y_train_over).value_counts())
# Out:
# SMOTE 적용 전 학습용 피처/레이블 데이터 세트 (417600, 3) (417600,)
# SMOTE 적용 후 학습용 피처/레이블 데이터 세트 (592968, 3) (592968,)
# SMOTE 적용 후 레이블 값 분포:
#  1.0    296484
# 0.0    296484
# dtype: int64

# %%
def make_dataset(data, label, window_size):
    feature_list = []
    label_list = []
    for i in range(len(data) - window_size):
        feature_list.append(np.array(data.iloc[i:i+window_size]))
        label_list.append(np.array(label.iloc[i+window_size]))
    return np.array(feature_list), np.array(label_list)

# %%
X_train_over = pd.DataFrame(X_train_over, columns = ['MELT_TEMP', 'MOTORSPEED', 'MELT_WEIGHT'])
y_train_over = pd.DataFrame(y_train_over, columns = ['TAG'])

# %%
#train dataset
train_feature, train_label = make_dataset(X_train_over, y_train_over, 10)

# %%
test_sc = pd.DataFrame(test_sc, columns = ['MELT_TEMP', 'MOTORSPEED', 'MELT_WEIGHT','TAG'])

# %%
feature_cols = ['MELT_TEMP', 'MOTORSPEED', 'MELT_WEIGHT']
label_cols = ['TAG']

# %%
test_feature = test_sc[feature_cols]
test_label = test_sc[label_cols]

# test dataset (실제 예측 해볼 데이터)
test_feature, test_label = make_dataset(test_feature, test_label, 10)
test_feature.shape, test_label.shape
# Out:
# ((417590, 10, 3), (417590, 1))

# %%
x_train, x_valid, y_train, y_valid = train_test_split(train_feature, train_label, test_size = 0.3,random_state=1)
x_train.shape, x_valid.shape
# Out:
# ((415070, 10, 3), (177888, 10, 3))

# %%
import os
path = "C:/Users/islab/Desktop/jihyeon/전자제조시스템"
os.chdir(path)

# %%
model_path = path

# %%
model = Sequential()
model.add(LSTM(50, 
               input_shape = (train_feature.shape[1], train_feature.shape[2]), activation = 'tanh', return_sequences = True))
model.add(Dropout(0.3))
model.add(LSTM(50, return_sequences = True))
model.add(Dropout(0.3))
model.add(LSTM(50, return_sequences = False))
model.add(Dense(1, activation = 'sigmoid'))

# %%
model.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics = ['accuracy'])
early_stop = EarlyStopping(monitor = 'val_loss', patience = 8)
filename = os.path.join(model_path, 'tmp_checkpoint.h5')
checkpoint = ModelCheckpoint(filename, monitor = 'val_loss', verbose = 1, save_best_only = True, mode = 'auto')

# %%
history = model.fit(x_train, y_train, epochs = 200, batch_size = 10, validation_data = (x_valid, y_valid), callbacks = [early_stop, checkpoint])
# Out:
# Epoch 1/200
# 41503/41507 [============================>.] - ETA: 0s - loss: 0.3486 - accuracy: 0.8115
# Epoch 1: val_loss improved from inf to 0.33420, saving model to C:/Users/islab/Desktop/jihyeon/전자제조시스템\tmp_checkpoint.h5
# 41507/41507 [==============================] - 341s 8ms/step - loss: 0.3486 - accuracy: 0.8115 - val_loss: 0.3342 - val_accuracy: 0.8194
# Epoch 2/200
# 41504/41507 [============================>.] - ETA: 0s - loss: 0.3337 - accuracy: 0.8191
# Epoch 2: val_loss did not improve from 0.33420
# 41507/41507 [==============================] - 345s 8ms/step - loss: 0.3337 - accuracy: 0.8191 - val_loss: 0.3365 - val_accuracy: 0.8147
# Epoch 3/200
# 41507/41507 [==============================] - ETA: 0s - loss: 0.3328 - accuracy: 0.8198
# Epoch 3: val_loss improved from 0.33420 to 0.33277, saving model to C:/Users/islab/Desktop/jihyeon/전자제조시스템\tmp_checkpoint.h5
# 41507/41507 [==============================] - 342s 8ms/step - loss: 0.3328 - accuracy: 0.8198 - val_loss: 0.3328 - val_accuracy: 0.8194
# Epoch 4/200
# 41503/41507 [============================>.] - ETA: 0s - loss: 0.3323 - accuracy: 0.8201
# Epoch 4: val_loss did not improve from 0.33277
# 41507/41507 [==============================] - 346s 8ms/step - loss: 0.3323 - accuracy: 0.8201 - val_loss: 0.3332 - val_accuracy: 0.8182
# Epoch 5/200
# 41502/41507 [============================>.] - ETA: 0s - loss: 0.3316 - accuracy: 0.8205
# Epoch 5: val_loss improved from 0.33277 to 0.33114, saving model to C:/Users/islab/Desktop/jihyeon/전자제조시스템\tmp_checkpoint.h5
# 41507/41507 [==============================] - 340s 8ms/step - loss: 0.3316 - accuracy: 0.8205 - val_loss: 0.3311 - val_accuracy: 0.8213
# Epoch 6/200
# 41506/41507 [============================>.] - ETA: 0s - loss: 0.3315 - accuracy: 0.8210
# Epoch 6: val_loss did not improve from 0.33114
# 41507/41507 [==============================] - 345s 8ms/step - loss: 0.3315 - accuracy: 0.8210 - val_loss: 0.3319 - val_accuracy: 0.8170
# Epoch 7/200
# 41502/41507 [============================>.] - ETA: 0s - loss: 0.3310 - accuracy: 0.8209
# Epoch 7: val_loss did not improve from 0.33114
# 41507/41507 [==============================] - 344s 8ms/step - loss: 0.3310 - accuracy: 0.8209 - val_loss: 0.3345 - val_accuracy: 0.8181
# Epoch 8/200
# 41507/41507 [==============================] - ETA: 0s - loss: 0.3317 - accuracy: 0.8207
# Epoch 8: val_loss did not improve from 0.33114
# 41507/41507 [==============================] - 345s 8ms/step - loss: 0.3317 - accuracy: 0.8207 - val_loss: 0.3329 - val_accuracy: 0.8170
# Epoch 9/200
# 41506/41507 [============================>.] - ETA: 0s - loss: 0.3311 - accuracy: 0.8211
# Epoch 9: val_loss did not improve from 0.33114
# 41507/41507 [==============================] - 350s 8ms/step - loss: 0.3311 - accuracy: 0.8211 - val_loss: 0.3321 - val_accuracy: 0.8202
# Epoch 10/200
# 41505/41507 [============================>.] - ETA: 0s - loss: 0.3307 - accuracy: 0.8215
# Epoch 10: val_loss improved from 0.33114 to 0.33029, saving model to C:/Users/islab/Desktop/jihyeon/전자제조시스템\tmp_checkpoint.h5
# 41507/41507 [==============================] - 343s 8ms/step - loss: 0.3307 - accuracy: 0.8215 - val_loss: 0.3303 - val_accuracy: 0.8204
# Epoch 11/200
# 41500/41507 [============================>.] - ETA: 0s - loss: 0.3304 - accuracy: 0.8215
# Epoch 11: val_loss did not improve from 0.33029
# 41507/41507 [==============================] - 347s 8ms/step - loss: 0.3304 - accuracy: 0.8215 - val_loss: 0.3307 - val_accuracy: 0.8212
# Epoch 12/200
# 41502/41507 [============================>.] - ETA: 0s - loss: 0.3304 - accuracy: 0.8218
# Epoch 12: val_loss improved from 0.33029 to 0.33001, saving model to C:/Users/islab/Desktop/jihyeon/전자제조시스템\tmp_checkpoint.h5
# 41507/41507 [==============================] - 343s 8ms/step - loss: 0.3304 - accuracy: 0.8218 - val_loss: 0.3300 - val_accuracy: 0.8226
# Epoch 13/200
# 41505/41507 [============================>.] - ETA: 0s - loss: 0.3304 - accuracy: 0.8220
# Epoch 13: val_loss did not improve from 0.33001
# 41507/41507 [==============================] - 343s 8ms/step - loss: 0.3304 - accuracy: 0.8220 - val_loss: 0.3310 - val_accuracy: 0.8202
# Epoch 14/200
# 41504/41507 [============================>.] - ETA: 0s - loss: 0.3314 - accuracy: 0.8211
# Epoch 14: val_loss did not improve from 0.33001
# 41507/41507 [==============================] - 344s 8ms/step - loss: 0.3314 - accuracy: 0.8211 - val_loss: 0.3307 - val_accuracy: 0.8190
# Epoch 15/200
# 41501/41507 [============================>.] - ETA: 0s - loss: 0.3301 - accuracy: 0.8218
# Epoch 15: val_loss did not improve from 0.33001
# 41507/41507 [==============================] - 339s 8ms/step - loss: 0.3301 - accuracy: 0.8219 - val_loss: 0.3310 - val_accuracy: 0.8189
# Epoch 16/200
# 41502/41507 [============================>.] - ETA: 0s - loss: 0.3304 - accuracy: 0.8220
# Epoch 16: val_loss did not improve from 0.33001
# 41507/41507 [==============================] - 344s 8ms/step - loss: 0.3304 - accuracy: 0.8220 - val_loss: 0.3332 - val_accuracy: 0.8183
# Epoch 17/200
# 41505/41507 [============================>.] - ETA: 0s - loss: 0.3301 - accuracy: 0.8223
# Epoch 17: val_loss did not improve from 0.33001
# 41507/41507 [==============================] - 342s 8ms/step - loss: 0.3301 - accuracy: 0.8223 - val_loss: 0.3306 - val_accuracy: 0.8223
# Epoch 18/200
# 41506/41507 [============================>.] - ETA: 0s - loss: 0.3303 - accuracy: 0.8221
# Epoch 18: val_loss did not improve from 0.33001
# 41507/41507 [==============================] - 335s 8ms/step - loss: 0.3303 - accuracy: 0.8221 - val_loss: 0.3306 - val_accuracy: 0.8204
# Epoch 19/200
# 41505/41507 [============================>.] - ETA: 0s - loss: 0.3302 - accuracy: 0.8218
# Epoch 19: val_loss did not improve from 0.33001
# 41507/41507 [==============================] - 342s 8ms/step - loss: 0.3302 - accuracy: 0.8218 - val_loss: 0.3324 - val_accuracy: 0.8187
# Epoch 20/200
# 41504/41507 [============================>.] - ETA: 0s - loss: 0.3301 - accuracy: 0.8220
# Epoch 20: val_loss did not improve from 0.33001
# 41507/41507 [==============================] - 339s 8ms/step - loss: 0.3301 - accuracy: 0.8220 - val_loss: 0.3313 - val_accuracy: 0.8202

# %%
pred = model.predict(test_feature)
# Out:
# 13050/13050 [==============================] - 47s 4ms/step

# %%
plt.plot(history.history["loss"],label="train")
plt.plot(history.history["val_loss"],label="validation")
plt.legend()
plt.show()

# %%
pred_df = pd.DataFrame(pred, columns=['TAG'])

pred_df['TAG'] = pred_df['TAG'].apply(lambda x: 1 if x>=0.5 else 0)

# %%
confusion = confusion_matrix(test_label, pred_df)
print(confusion)
# Out:
# [[  7380  48567]
#  [ 47111 314532]]

# %%
plot = sns.heatmap(confusion ,square=True, annot=True, fmt='d', cmap='terrain')
class_lables=['0','1','2','3']
plt.title("confusrion", size = 12)
plot.set_xlabel('예측 y값')
plot.set_ylabel('실제 y값')
# plt.savefig('80% 사후확률_min_{}_수정.png'.format(j), dpi=300, transparent=True, bbox_inches="tight")
plt.show()

# %%
p = precision_score(test_label, pred_df)
print('precision : %0.5f' %p)
r = recall_score(test_label, pred_df)
print('recall : %0.5f' %r)
f1 = f1_score(test_label, pred_df)
print('f1-score : %0.5f' %f1)
acc = accuracy_score(test_label, pred_df)
print('accuracy : %0.5f' %acc)
# Out:
# precision : 0.86624
# recall : 0.86973
# f1-score : 0.86798
# accuracy : 0.77088

# %%
# test_label
test_df = pd.DataFrame(test_label, columns=['TAG'])
test_df
# Out:
#         TAG
# 0       0.0
# 1       0.0
# 2       1.0
# 3       0.0
# 4       1.0
# ...     ...
# 417585  1.0
# 417586  1.0
# 417587  1.0
# 417588  1.0
# 417589  1.0
#
# [417590 rows x 1 columns]

# %%
pred_df
# Out:
#         TAG
# 0         0
# 1         0
# 2         0
# 3         0
# 4         1
# ...     ...
# 417585    1
# 417586    1
# 417587    1
# 417588    1
# 417589    1
#
# [417590 rows x 1 columns]

# %%
test_1 = df1[split_date:]
test_2 = test_1[10:]
test_2
x = test_2['TAG'].values.tolist()
# test_1

# %%
c = confusion_matrix(x, test_df)
print(c)
# Out:
# [[ 55947      0]
#  [     0 361643]]

# %%
y = pred_df['TAG'].values.tolist()

# %%
test_2['predict'] = y
test_2
# Out:
# C:\Users\islab\AppData\Local\Temp\ipykernel_9404\1846207918.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_2['predict'] = y
#                      MELT_TEMP  MOTORSPEED  MELT_WEIGHT  TAG  predict
# STD_DT
# 2020-04-02 00:01:00        454         149          728    0        0
# 2020-04-02 00:01:00        463           0          727    0        0
# 2020-04-02 00:01:00        496         166          725    1        0
# 2020-04-02 00:01:00        389         203          724    0        0
# 2020-04-02 00:01:00        780        1749          723    1        1
# ...                        ...         ...          ...  ...      ...
# 2020-04-30 23:59:00        755        1743          318    1        1
# 2020-04-30 23:59:00        385         206          317    1        1
# 2020-04-30 23:59:00        465         148          316    1        1
# 2020-04-30 23:59:00        467           0          314    1        1
# 2020-04-30 23:59:00        453         125          312    1        1
#
# [417590 rows x 5 columns]

# %%
test_2.to_csv('사후확률_1.csv')

# %%
test_2
# Out:
#                      MELT_TEMP  MOTORSPEED  MELT_WEIGHT  TAG
# STD_DT
# 2020-04-02 00:01:00        454         149          728    0
# 2020-04-02 00:01:00        463           0          727    0
# 2020-04-02 00:01:00        496         166          725    1
# 2020-04-02 00:01:00        389         203          724    0
# 2020-04-02 00:01:00        780        1749          723    1
# ...                        ...         ...          ...  ...
# 2020-04-30 23:59:00        755        1743          318    1
# 2020-04-30 23:59:00        385         206          317    1
# 2020-04-30 23:59:00        465         148          316    1
# 2020-04-30 23:59:00        467           0          314    1
# 2020-04-30 23:59:00        453         125          312    1
#
# [417590 rows x 4 columns]
